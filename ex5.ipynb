# %%
from PIL import Image
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset
from torch import nn
from tqdm.auto import tqdm
import torchvision
import torch.optim as optim
from typing import Dict, List, Tuple
from sklearn.preprocessing import MinMaxScaler
import torch.nn.functional as F
from torch.autograd import Variable

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# !unzip pic_encoder
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: landscape Images/gray/2915.jpg
#   inflating: landscape Images/gray/2916.jpg
#   inflating: landscape Images/gray/2917.jpg
#   inflating: landscape Images/gray/2918.jpg
#   inflating: landscape Images/gray/2919.jpg
#   inflating: landscape Images/gray/292.jpg
#   inflating: landscape Images/gray/2920.jpg
#   inflating: landscape Images/gray/2921.jpg
#   inflating: landscape Images/gray/2922.jpg
#   inflating: landscape Images/gray/2923.jpg
#   inflating: landscape Images/gray/2924.jpg
#   inflating: landscape Images/gray/2925.jpg
#   inflating: landscape Images/gray/2926.jpg
#   inflating: landscape Images/gray/2927.jpg
#   inflating: landscape Images/gray/2928.jpg
#   inflating: landscape Images/gray/2929.jpg
#   inflating: landscape Images/gray/293.jpg
#   inflating: landscape Images/gray/2930.jpg
#   inflating: landscape Images/gray/2931.jpg
#   inflating: landscape Images/gray/2932.jpg
#   inflating: landscape Images/gray/2933.jpg
#   inflating: landscape Images/gray/2934.jpg
#   inflating: landscape Images/gray/2935.jpg
#   inflating: landscape Images/gray/2936.jpg
#   inflating: landscape Images/gray/2937.jpg
#   inflating: landscape Images/gray/2938.jpg
#   inflating: landscape Images/gray/2939.jpg
#   inflating: landscape Images/gray/294.jpg
#   inflating: landscape Images/gray/2940.jpg
#   inflating: landscape Images/gray/2941.jpg
#   inflating: landscape Images/gray/2942.jpg
#   inflating: landscape Images/gray/2943.jpg
#   inflating: landscape Images/gray/2944.jpg
#   inflating: landscape Images/gray/2945.jpg
#   inflating: landscape Images/gray/2946.jpg
#   inflating: landscape Images/gray/2947.jpg
#   inflating: landscape Images/gray/2948.jpg
#   inflating: landscape Images/gray/2949.jpg
#   inflating: landscape Images/gray/295.jpg
#   inflating: landscape Images/gray/2950.jpg
#   inflating: landscape Images/gray/2951.jpg
#   inflating: landscape Images/gray/2952.jpg
#   inflating: landscape Images/gray/2953.jpg
#   inflating: landscape Images/gray/2954.jpg
#   inflating: landscape Images/gray/2955.jpg
#   inflating: landscape Images/gray/2956.jpg
#   inflating: landscape Images/gray/2957.jpg
#   inflating: landscape Images/gray/2958.jpg
#   inflating: landscape Images/gray/2959.jpg
#   inflating: landscape Images/gray/296.jpg
#   inflating: landscape Images/gray/2960.jpg
#   inflating: landscape Images/gray/2961.jpg
#   inflating: landscape Images/gray/2962.jpg
#   inflating: landscape Images/gray/2963.jpg
#   inflating: landscape Images/gray/2964.jpg
#   inflating: landscape Images/gray/2965.jpg
#   inflating: landscape Images/gray/2966.jpg
#   inflating: landscape Images/gray/2967.jpg
#   inflating: landscape Images/gray/2968.jpg
#   inflating: landscape Images/gray/2969.jpg
#   inflating: landscape Images/gray/297.jpg
#   inflating: landscape Images/gray/2970.jpg
#   inflating: landscape Images/gray/2971.jpg
#   inflating: landscape Images/gray/2972.jpg
#   inflating: landscape Images/gray/2973.jpg
#   inflating: landscape Images/gray/2974.jpg
#   inflating: landscape Images/gray/2975.jpg
#   inflating: landscape Images/gray/2976.jpg
#   inflating: landscape Images/gray/2977.jpg
#   inflating: landscape Images/gray/2978.jpg
#   inflating: landscape Images/gray/2979.jpg
#   inflating: landscape Images/gray/298.jpg
#   inflating: landscape Images/gray/2980.jpg
#   inflating: landscape Images/gray/2981.jpg
#   inflating: landscape Images/gray/2982.jpg
#   inflating: landscape Images/gray/2983.jpg
#   inflating: landscape Images/gray/2984.jpg
#   inflating: landscape Images/gray/2985.jpg
#   inflating: landscape Images/gray/2986.jpg
#   inflating: landscape Images/gray/2987.jpg
#   inflating: landscape Images/gray/2988.jpg
#   inflating: landscape Images/gray/2989.jpg
#   inflating: landscape Images/gray/299.jpg
#   inflating: landscape Images/gray/2990.jpg
#   inflating: landscape Images/gray/2991.jpg
#   inflating: landscape Images/gray/2992.jpg
#   inflating: landscape Images/gray/2993.jpg
#   inflating: landscape Images/gray/2994.jpg
#   inflating: landscape Images/gray/2995.jpg
#   inflating: landscape Images/gray/2996.jpg
#   inflating: landscape Images/gray/2997.jpg
#   inflating: landscape Images/gray/2998.jpg
#   inflating: landscape Images/gray/2999.jpg
#   inflating: landscape Images/gray/3.jpg
#   inflating: landscape Images/gray/30.jpg
#   inflating: landscape Images/gray/300.jpg
#   inflating: landscape Images/gray/3000.jpg
#   inflating: landscape Images/gray/3001.jpg
#   inflating: landscape Images/gray/3002.jpg
#   inflating: landscape Images/gray/3003.jpg
#   inflating: landscape Images/gray/3004.jpg
#   inflating: landscape Images/gray/3005.jpg
#   inflating: landscape Images/gray/3006.jpg
#   inflating: landscape Images/gray/3007.jpg
#   inflating: landscape Images/gray/3008.jpg
#   inflating: landscape Images/gray/3009.jpg
#   inflating: landscape Images/gray/301.jpg
#   inflating: landscape Images/gray/3010.jpg
#   inflating: landscape Images/gray/3011.jpg
#   inflating: landscape Images/gray/3012.jpg
#   inflating: landscape Images/gray/3013.jpg
#   inflating: landscape Images/gray/3014.jpg
#   inflating: landscape Images/gray/3015.jpg
#   inflating: landscape Images/gray/3016.jpg
#   inflating: landscape Images/gray/3017.jpg
#   inflating: landscape Images/gray/3018.jpg
#   inflating: landscape Images/gray/3019.jpg
#   inflating: landscape Images/gray/302.jpg
#   inflating: landscape Images/gray/3020.jpg
#   inflating: landscape Images/gray/3021.jpg
#   inflating: landscape Images/gray/3022.jpg
#   inflating: landscape Images/gray/3023.jpg
#   inflating: landscape Images/gray/3024.jpg
#   inflating: landscape Images/gray/3025.jpg
#   inflating: landscape Images/gray/3026.jpg
#   inflating: landscape Images/gray/3027.jpg
#   inflating: landscape Images/gray/3028.jpg
#   inflating: landscape Images/gray/3029.jpg
#   inflating: landscape Images/gray/303.jpg
#   inflating: landscape Images/gray/3030.jpg
#   inflating: landscape Images/gray/3031.jpg
#   inflating: landscape Images/gray/3032.jpg
#   inflating: landscape Images/gray/3033.jpg
#   inflating: landscape Images/gray/3034.jpg
#   inflating: landscape Images/gray/3035.jpg
#   inflating: landscape Images/gray/3036.jpg
#   inflating: landscape Images/gray/3037.jpg
#   inflating: landscape Images/gray/3038.jpg
#   inflating: landscape Images/gray/3039.jpg
#   inflating: landscape Images/gray/304.jpg
#   inflating: landscape Images/gray/3040.jpg
#   inflating: landscape Images/gray/3041.jpg
#   inflating: landscape Images/gray/3042.jpg
#   inflating: landscape Images/gray/3043.jpg
#   inflating: landscape Images/gray/3044.jpg
#   inflating: landscape Images/gray/3045.jpg
#   inflating: landscape Images/gray/3046.jpg
#   inflating: landscape Images/gray/3047.jpg
#   inflating: landscape Images/gray/3048.jpg
#   inflating: landscape Images/gray/3049.jpg
#   inflating: landscape Images/gray/305.jpg
#   inflating: landscape Images/gray/3050.jpg
#   inflating: landscape Images/gray/3051.jpg
#   inflating: landscape Images/gray/3052.jpg
#   inflating: landscape Images/gray/3053.jpg
#   inflating: landscape Images/gray/3054.jpg
#   inflating: landscape Images/gray/3055.jpg
#   inflating: landscape Images/gray/3056.jpg
#   inflating: landscape Images/gray/3057.jpg
#   inflating: landscape Images/gray/3058.jpg
#   inflating: landscape Images/gray/3059.jpg
#   inflating: landscape Images/gray/306.jpg
#   inflating: landscape Images/gray/3060.jpg
#   inflating: landscape Images/gray/3061.jpg
#   inflating: landscape Images/gray/3062.jpg
#   inflating: landscape Images/gray/3063.jpg
#   inflating: landscape Images/gray/3064.jpg
#   inflating: landscape Images/gray/3065.jpg
#   inflating: landscape Images/gray/3066.jpg
#   inflating: landscape Images/gray/3067.jpg
#   inflating: landscape Images/gray/3068.jpg
#   inflating: landscape Images/gray/3069.jpg
#   inflating: landscape Images/gray/307.jpg
#   inflating: landscape Images/gray/3070.jpg
#   inflating: landscape Images/gray/3071.jpg
#   inflating: landscape Images/gray/3072.jpg
#   inflating: landscape Images/gray/3073.jpg
#   inflating: landscape Images/gray/3074.jpg
#   inflating: landscape Images/gray/3075.jpg
#   inflating: landscape Images/gray/3076.jpg
#   inflating: landscape Images/gray/3077.jpg
#   inflating: landscape Images/gray/3078.jpg
#   inflating: landscape Images/gray/3079.jpg
#   inflating: landscape Images/gray/308.jpg
#   inflating: landscape Images/gray/3080.jpg
#   inflating: landscape Images/gray/3081.jpg
#   inflating: landscape Images/gray/3082.jpg
#   inflating: landscape Images/gray/3083.jpg
#   inflating: landscape Images/gray/3084.jpg
#   inflating: landscape Images/gray/3085.jpg
#   inflating: landscape Images/gray/3086.jpg
#   inflating: landscape Images/gray/3087.jpg
#   inflating: landscape Images/gray/3088.jpg
#   inflating: landscape Images/gray/3089.jpg
#   inflating: landscape Images/gray/309.jpg
#   inflating: landscape Images/gray/3090.jpg
#   inflating: landscape Images/gray/3091.jpg
#   inflating: landscape Images/gray/3092.jpg
#   inflating: landscape Images/gray/3093.jpg
#   inflating: landscape Images/gray/3094.jpg
#   inflating: landscape Images/gray/3095.jpg
#   inflating: landscape Images/gray/3096.jpg
#   inflating: landscape Images/gray/3097.jpg
#   inflating: landscape Images/gray/3098.jpg
#   inflating: landscape Images/gray/3099.jpg
#   inflating: landscape Images/gray/31.jpg
#   inflating: landscape Images/gray/310.jpg
#   inflating: landscape Images/gray/3100.jpg
#   inflating: landscape Images/gray/3101.jpg
#   inflating: landscape Images/gray/3102.jpg
#   inflating: landscape Images/gray/3103.jpg
#   inflating: landscape Images/gray/3104.jpg
#   inflating: landscape Images/gray/3105.jpg
#   inflating: landscape Images/gray/3106.jpg
#   inflating: landscape Images/gray/3107.jpg
#   inflating: landscape Images/gray/3108.jpg
#   inflating: landscape Images/gray/3109.jpg
#   inflating: landscape Images/gray/311.jpg
#   inflating: landscape Images/gray/3110.jpg
#   inflating: landscape Images/gray/3111.jpg
#   inflating: landscape Images/gray/3112.jpg
#   inflating: landscape Images/gray/3113.jpg
#   inflating: landscape Images/gray/3114.jpg
#   inflating: landscape Images/gray/3115.jpg
#   inflating: landscape Images/gray/3116.jpg
#   inflating: landscape Images/gray/3117.jpg
#   inflating: landscape Images/gray/3118.jpg
#   inflating: landscape Images/gray/3119.jpg
#   inflating: landscape Images/gray/312.jpg
#   inflating: landscape Images/gray/3120.jpg
#   inflating: landscape Images/gray/3121.jpg
#   inflating: landscape Images/gray/3122.jpg
#   inflating: landscape Images/gray/3123.jpg
#   inflating: landscape Images/gray/3124.jpg
#   inflating: landscape Images/gray/3125.jpg
#   inflating: landscape Images/gray/3126.jpg
#   inflating: landscape Images/gray/3127.jpg
#   inflating: landscape Images/gray/3128.jpg
#   inflating: landscape Images/gray/3129.jpg
#   inflating: landscape Images/gray/313.jpg
#   inflating: landscape Images/gray/3130.jpg
#   inflating: landscape Images/gray/3131.jpg
#   inflating: landscape Images/gray/3132.jpg
#   inflating: landscape Images/gray/3133.jpg
#   inflating: landscape Images/gray/3134.jpg
#   inflating: landscape Images/gray/3135.jpg
#   inflating: landscape Images/gray/3136.jpg
#   inflating: landscape Images/gray/3137.jpg
#   inflating: landscape Images/gray/3138.jpg
#   inflating: landscape Images/gray/3139.jpg
#   inflating: landscape Images/gray/314.jpg
#   inflating: landscape Images/gray/3140.jpg
#   inflating: landscape Images/gray/3141.jpg
#   inflating: landscape Images/gray/3142.jpg
#   inflating: landscape Images/gray/3143.jpg
#   inflating: landscape Images/gray/3144.jpg
#   inflating: landscape Images/gray/3145.jpg
#   inflating: landscape Images/gray/3146.jpg
#   inflating: landscape Images/gray/3147.jpg
#   inflating: landscape Images/gray/3148.jpg
#   inflating: landscape Images/gray/3149.jpg
#   inflating: landscape Images/gray/315.jpg
#   inflating: landscape Images/gray/3150.jpg
#   inflating: landscape Images/gray/3151.jpg
#   inflating: landscape Images/gray/3152.jpg
#   inflating: landscape Images/gray/3153.jpg
#   inflating: landscape Images/gray/3154.jpg
#   inflating: landscape Images/gray/3155.jpg
#   inflating: landscape Images/gray/3156.jpg
#   inflating: landscape Images/gray/3157.jpg
#   inflating: landscape Images/gray/3158.jpg
#   inflating: landscape Images/gray/3159.jpg
#   inflating: landscape Images/gray/316.jpg
#   inflating: landscape Images/gray/3160.jpg
#   inflating: landscape Images/gray/3161.jpg
#   inflating: landscape Images/gray/3162.jpg
#   inflating: landscape Images/gray/3163.jpg
#   inflating: landscape Images/gray/3164.jpg
#   inflating: landscape Images/gray/3165.jpg
#   inflating: landscape Images/gray/3166.jpg
#   inflating: landscape Images/gray/3167.jpg
#   inflating: landscape Images/gray/3168.jpg
#   inflating: landscape Images/gray/3169.jpg
#   inflating: landscape Images/gray/317.jpg
#   inflating: landscape Images/gray/3170.jpg
#   inflating: landscape Images/gray/3171.jpg
#   inflating: landscape Images/gray/3172.jpg
#   inflating: landscape Images/gray/3173.jpg
#   inflating: landscape Images/gray/3174.jpg
#   inflating: landscape Images/gray/3175.jpg
#   inflating: landscape Images/gray/3176.jpg
#   inflating: landscape Images/gray/3177.jpg
#   inflating: landscape Images/gray/3178.jpg
#   inflating: landscape Images/gray/3179.jpg
#   inflating: landscape Images/gray/318.jpg
#   inflating: landscape Images/gray/3180.jpg
#   inflating: landscape Images/gray/3181.jpg
#   inflating: landscape Images/gray/3182.jpg
#   inflating: landscape Images/gray/3183.jpg
#   inflating: landscape Images/gray/3184.jpg
#   inflating: landscape Images/gray/3185.jpg
#   inflating: landscape Images/gray/3186.jpg
#   inflating: landscape Images/gray/3187.jpg
#   inflating: landscape Images/gray/3188.jpg
#   inflating: landscape Images/gray/3189.jpg
#   inflating: landscape Images/gray/319.jpg
#   inflating: landscape Images/gray/3190.jpg
#   inflating: landscape Images/gray/3191.jpg
#   inflating: landscape Images/gray/3192.jpg
#   inflating: landscape Images/gray/3193.jpg
#   inflating: landscape Images/gray/3194.jpg
#   inflating: landscape Images/gray/3195.jpg
#   inflating: landscape Images/gray/3196.jpg
#   inflating: landscape Images/gray/3197.jpg
#   inflating: landscape Images/gray/3198.jpg
#   inflating: landscape Images/gray/3199.jpg
#   inflating: landscape Images/gray/32.jpg
#   inflating: landscape Images/gray/320.jpg
#   inflating: landscape Images/gray/3200.jpg
#   inflating: landscape Images/gray/3201.jpg
#   inflating: landscape Images/gray/3202.jpg
#   inflating: landscape Images/gray/3203.jpg
#   inflating: landscape Images/gray/3204.jpg
#   inflating: landscape Images/gray/3205.jpg
#   inflating: landscape Images/gray/3206.jpg
#   inflating: landscape Images/gray/3207.jpg
#   inflating: landscape Images/gray/3208.jpg
#   inflating: landscape Images/gray/3209.jpg
#   inflating: landscape Images/gray/321.jpg
#   inflating: landscape Images/gray/3210.jpg
#   inflating: landscape Images/gray/3211.jpg
#   inflating: landscape Images/gray/3212.jpg
#   inflating: landscape Images/gray/3213.jpg
#   inflating: landscape Images/gray/3214.jpg
#   inflating: landscape Images/gray/3215.jpg
#   inflating: landscape Images/gray/3216.jpg
#   inflating: landscape Images/gray/3217.jpg
#   inflating: landscape Images/gray/3218.jpg
#   inflating: landscape Images/gray/3219.jpg
#   inflating: landscape Images/gray/322.jpg
#   inflating: landscape Images/gray/3220.jpg
#   inflating: landscape Images/gray/3221.jpg
#   inflating: landscape Images/gray/3222.jpg
#   inflating: landscape Images/gray/3223.jpg
#   inflating: landscape Images/gray/3224.jpg
#   inflating: landscape Images/gray/3225.jpg
#   inflating: landscape Images/gray/3226.jpg
#   inflating: landscape Images/gray/3227.jpg
#   inflating: landscape Images/gray/3228.jpg
#   inflating: landscape Images/gray/3229.jpg
#   inflating: landscape Images/gray/323.jpg
#   inflating: landscape Images/gray/3230.jpg
#   inflating: landscape Images/gray/3231.jpg
#   inflating: landscape Images/gray/3232.jpg
#   inflating: landscape Images/gray/3233.jpg
#   inflating: landscape Images/gray/3234.jpg
#   inflating: landscape Images/gray/3235.jpg
#   inflating: landscape Images/gray/3236.jpg
#   inflating: landscape Images/gray/3237.jpg
#   inflating: landscape Images/gray/3238.jpg
#   inflating: landscape Images/gray/3239.jpg
#   inflating: landscape Images/gray/324.jpg
#   inflating: landscape Images/gray/3240.jpg
#   inflating: landscape Images/gray/3241.jpg
#   inflating: landscape Images/gray/3242.jpg
#   inflating: landscape Images/gray/3243.jpg
#   inflating: landscape Images/gray/3244.jpg
#   inflating: landscape Images/gray/3245.jpg
#   inflating: landscape Images/gray/3246.jpg
#   inflating: landscape Images/gray/3247.jpg
#   inflating: landscape Images/gray/3248.jpg
#   inflating: landscape Images/gray/3249.jpg
#   inflating: landscape Images/gray/325.jpg
#   inflating: landscape Images/gray/3250.jpg
#   inflating: landscape Images/gray/3251.jpg
#   inflating: landscape Images/gray/3252.jpg
#   inflating: landscape Images/gray/3253.jpg
#   inflating: landscape Images/gray/3254.jpg
#   inflating: landscape Images/gray/3255.jpg
#   inflating: landscape Images/gray/3256.jpg
#   inflating: landscape Images/gray/3257.jpg
#   inflating: landscape Images/gray/3258.jpg
#   inflating: landscape Images/gray/3259.jpg
#   inflating: landscape Images/gray/326.jpg
#   inflating: landscape Images/gray/3260.jpg
#   inflating: landscape Images/gray/3261.jpg
#   inflating: landscape Images/gray/3262.jpg
#   inflating: landscape Images/gray/3263.jpg
#   inflating: landscape Images/gray/3264.jpg
#   inflating: landscape Images/gray/3265.jpg
#   inflating: landscape Images/gray/3266.jpg
#   inflating: landscape Images/gray/3267.jpg
#   inflating: landscape Images/gray/3268.jpg
#   inflating: landscape Images/gray/3269.jpg
#   inflating: landscape Images/gray/327.jpg
#   inflating: landscape Images/gray/3270.jpg
#   inflating: landscape Images/gray/3271.jpg
#   inflating: landscape Images/gray/3272.jpg
#   inflating: landscape Images/gray/3273.jpg
#   inflating: landscape Images/gray/3274.jpg
#   inflating: landscape Images/gray/3275.jpg
#   inflating: landscape Images/gray/3276.jpg
#   inflating: landscape Images/gray/3277.jpg
#   inflating: landscape Images/gray/3278.jpg
#   inflating: landscape Images/gray/3279.jpg
#   inflating: landscape Images/gray/328.jpg
#   inflating: landscape Images/gray/3280.jpg
#   inflating: landscape Images/gray/3281.jpg
#   inflating: landscape Images/gray/3282.jpg
#   inflating: landscape Images/gray/3283.jpg
#   inflating: landscape Images/gray/3284.jpg
#   inflating: landscape Images/gray/3285.jpg
#   inflating: landscape Images/gray/3286.jpg
#   inflating: landscape Images/gray/3287.jpg
#   inflating: landscape Images/gray/3288.jpg
#   inflating: landscape Images/gray/3289.jpg
#   inflating: landscape Images/gray/329.jpg
#   inflating: landscape Images/gray/3290.jpg
#   inflating: landscape Images/gray/3291.jpg
#   inflating: landscape Images/gray/3292.jpg
#   inflating: landscape Images/gray/3293.jpg
#   inflating: landscape Images/gray/3294.jpg
#   inflating: landscape Images/gray/3295.jpg
#   inflating: landscape Images/gray/3296.jpg
#   inflating: landscape Images/gray/3297.jpg
#   inflating: landscape Images/gray/3298.jpg
#   inflating: landscape Images/gray/3299.jpg
#   inflating: landscape Images/gray/33.jpg
#   inflating: landscape Images/gray/330.jpg
#   inflating: landscape Images/gray/3300.jpg
#   inflating: landscape Images/gray/3301.jpg
#   inflating: landscape Images/gray/3302.jpg
#   inflating: landscape Images/gray/3303.jpg
#   inflating: landscape Images/gray/3304.jpg
#   inflating: landscape Images/gray/3305.jpg
#   inflating: landscape Images/gray/3306.jpg
#   inflating: landscape Images/gray/3307.jpg
#   inflating: landscape Images/gray/3308.jpg
#   inflating: landscape Images/gray/3309.jpg
#   inflating: landscape Images/gray/331.jpg
#   inflating: landscape Images/gray/3310.jpg
#   inflating: landscape Images/gray/3311.jpg
#   inflating: landscape Images/gray/3312.jpg
#   inflating: landscape Images/gray/3313.jpg
#   inflating: landscape Images/gray/3314.jpg
#   inflating: landscape Images/gray/3315.jpg
#   inflating: landscape Images/gray/3316.jpg
#   inflating: landscape Images/gray/3317.jpg
#   inflating: landscape Images/gray/3318.jpg
#   inflating: landscape Images/gray/3319.jpg
#   inflating: landscape Images/gray/332.jpg
#   inflating: landscape Images/gray/3320.jpg
#   inflating: landscape Images/gray/3321.jpg
#   inflating: landscape Images/gray/3322.jpg
#   inflating: landscape Images/gray/3323.jpg
#   inflating: landscape Images/gray/3324.jpg
#   inflating: landscape Images/gray/3325.jpg
#   inflating: landscape Images/gray/3326.jpg
#   inflating: landscape Images/gray/3327.jpg
#   inflating: landscape Images/gray/3328.jpg
#   inflating: landscape Images/gray/3329.jpg
#   inflating: landscape Images/gray/333.jpg
#   inflating: landscape Images/gray/3330.jpg
#   inflating: landscape Images/gray/3331.jpg
#   inflating: landscape Images/gray/3332.jpg
#   inflating: landscape Images/gray/3333.jpg
#   inflating: landscape Images/gray/3334.jpg
#   inflating: landscape Images/gray/3335.jpg
#   inflating: landscape Images/gray/3336.jpg
#   inflating: landscape Images/gray/3337.jpg
#   inflating: landscape Images/gray/3338.jpg
#   inflating: landscape Images/gray/3339.jpg
#   inflating: landscape Images/gray/334.jpg
#   inflating: landscape Images/gray/3340.jpg
#   inflating: landscape Images/gray/3341.jpg
#   inflating: landscape Images/gray/3342.jpg
#   inflating: landscape Images/gray/3343.jpg
#   inflating: landscape Images/gray/3344.jpg
#   inflating: landscape Images/gray/3345.jpg
#   inflating: landscape Images/gray/3346.jpg
#   inflating: landscape Images/gray/3347.jpg
#   inflating: landscape Images/gray/3348.jpg
#   inflating: landscape Images/gray/3349.jpg
#   inflating: landscape Images/gray/335.jpg
#   inflating: landscape Images/gray/3350.jpg
#   inflating: landscape Images/gray/3351.jpg
#   inflating: landscape Images/gray/3352.jpg
#   inflating: landscape Images/gray/3353.jpg
#   inflating: landscape Images/gray/3354.jpg
#   inflating: landscape Images/gray/3355.jpg
#   inflating: landscape Images/gray/3356.jpg
#   inflating: landscape Images/gray/3357.jpg
#   inflating: landscape Images/gray/3358.jpg
#   inflating: landscape Images/gray/3359.jpg
#   inflating: landscape Images/gray/336.jpg
#   inflating: landscape Images/gray/3360.jpg
#   inflating: landscape Images/gray/3361.jpg
#   inflating: landscape Images/gray/3362.jpg
#   inflating: landscape Images/gray/3363.jpg
#   inflating: landscape Images/gray/3364.jpg
#   inflating: landscape Images/gray/3365.jpg
#   inflating: landscape Images/gray/3366.jpg
#   inflating: landscape Images/gray/3367.jpg
#   inflating: landscape Images/gray/3368.jpg
#   inflating: landscape Images/gray/3369.jpg
#   inflating: landscape Images/gray/337.jpg
#   inflating: landscape Images/gray/3370.jpg
#   inflating: landscape Images/gray/3371.jpg
#   inflating: landscape Images/gray/3372.jpg
#   inflating: landscape Images/gray/3373.jpg
#   inflating: landscape Images/gray/3374.jpg
#   inflating: landscape Images/gray/3375.jpg
#   inflating: landscape Images/gray/3376.jpg
#   inflating: landscape Images/gray/3377.jpg
#   inflating: landscape Images/gray/3378.jpg
#   inflating: landscape Images/gray/3379.jpg
#   inflating: landscape Images/gray/338.jpg
#   inflating: landscape Images/gray/3380.jpg
#   inflating: landscape Images/gray/3381.jpg
#   inflating: landscape Images/gray/3382.jpg
#   inflating: landscape Images/gray/3383.jpg
#   inflating: landscape Images/gray/3384.jpg
#   inflating: landscape Images/gray/3385.jpg
#   inflating: landscape Images/gray/3386.jpg
#   inflating: landscape Images/gray/3387.jpg
#   inflating: landscape Images/gray/3388.jpg
#   inflating: landscape Images/gray/3389.jpg
#   inflating: landscape Images/gray/339.jpg
#   inflating: landscape Images/gray/3390.jpg
#   inflating: landscape Images/gray/3391.jpg
#   inflating: landscape Images/gray/3392.jpg
#   inflating: landscape Images/gray/3393.jpg
#   inflating: landscape Images/gray/3394.jpg
#   inflating: landscape Images/gray/3395.jpg
#   inflating: landscape Images/gray/3396.jpg
#   inflating: landscape Images/gray/3397.jpg
#   inflating: landscape Images/gray/3398.jpg
#   inflating: landscape Images/gray/3399.jpg
#   inflating: landscape Images/gray/34.jpg
#   inflating: landscape Images/gray/340.jpg
#   inflating: landscape Images/gray/3400.jpg
#   inflating: landscape Images/gray/3401.jpg
#   inflating: landscape Images/gray/3402.jpg
#   inflating: landscape Images/gray/3403.jpg
#   inflating: landscape Images/gray/3404.jpg
#   inflating: landscape Images/gray/3405.jpg
#   inflating: landscape Images/gray/3406.jpg
#   inflating: landscape Images/gray/3407.jpg
#   inflating: landscape Images/gray/3408.jpg
#   inflating: landscape Images/gray/3409.jpg
#   inflating: landscape Images/gray/341.jpg
#   inflating: landscape Images/gray/3410.jpg
#   inflating: landscape Images/gray/3411.jpg
#   inflating: landscape Images/gray/3412.jpg
#   inflating: landscape Images/gray/3413.jpg
#   inflating: landscape Images/gray/3414.jpg
#   inflating: landscape Images/gray/3415.jpg
#   inflating: landscape Images/gray/3416.jpg
#   inflating: landscape Images/gray/3417.jpg
#   inflating: landscape Images/gray/3418.jpg
#   inflating: landscape Images/gray/3419.jpg
#   inflating: landscape Images/gray/342.jpg
#   inflating: landscape Images/gray/3420.jpg
#   inflating: landscape Images/gray/3421.jpg
#   inflating: landscape Images/gray/3422.jpg
#   inflating: landscape Images/gray/3423.jpg
#   inflating: landscape Images/gray/3424.jpg
#   inflating: landscape Images/gray/3425.jpg
#   inflating: landscape Images/gray/3426.jpg
#   inflating: landscape Images/gray/3427.jpg
#   inflating: landscape Images/gray/3428.jpg
#   inflating: landscape Images/gray/3429.jpg
#   inflating: landscape Images/gray/343.jpg
#   inflating: landscape Images/gray/3430.jpg
#   inflating: landscape Images/gray/3431.jpg
#   inflating: landscape Images/gray/3432.jpg
#   inflating: landscape Images/gray/3433.jpg
#   inflating: landscape Images/gray/3434.jpg
#   inflating: landscape Images/gray/3435.jpg
#   inflating: landscape Images/gray/3436.jpg
#   inflating: landscape Images/gray/3437.jpg
#   inflating: landscape Images/gray/3438.jpg
#   inflating: landscape Images/gray/3439.jpg
#   inflating: landscape Images/gray/344.jpg
#   inflating: landscape Images/gray/3440.jpg
#   inflating: landscape Images/gray/3441.jpg
#   inflating: landscape Images/gray/3442.jpg
#   inflating: landscape Images/gray/3443.jpg
#   inflating: landscape Images/gray/3444.jpg
#   inflating: landscape Images/gray/3445.jpg
#   inflating: landscape Images/gray/3446.jpg
#   inflating: landscape Images/gray/3447.jpg
#   inflating: landscape Images/gray/3448.jpg
#   inflating: landscape Images/gray/3449.jpg
#   inflating: landscape Images/gray/345.jpg
#   inflating: landscape Images/gray/3450.jpg
#   inflating: landscape Images/gray/3451.jpg
#   inflating: landscape Images/gray/3452.jpg
#   inflating: landscape Images/gray/3453.jpg
#   inflating: landscape Images/gray/3454.jpg
#   inflating: landscape Images/gray/3455.jpg
#   inflating: landscape Images/gray/3456.jpg
#   inflating: landscape Images/gray/3457.jpg
#   inflating: landscape Images/gray/3458.jpg
#   inflating: landscape Images/gray/3459.jpg
#   inflating: landscape Images/gray/346.jpg
#   inflating: landscape Images/gray/3460.jpg
#   inflating: landscape Images/gray/3461.jpg
#   inflating: landscape Images/gray/3462.jpg
#   inflating: landscape Images/gray/3463.jpg
#   inflating: landscape Images/gray/3464.jpg
#   inflating: landscape Images/gray/3465.jpg
#   inflating: landscape Images/gray/3466.jpg
#   inflating: landscape Images/gray/3467.jpg
#   inflating: landscape Images/gray/3468.jpg
#   inflating: landscape Images/gray/3469.jpg
#   inflating: landscape Images/gray/347.jpg
#   inflating: landscape Images/gray/3470.jpg
#   inflating: landscape Images/gray/3471.jpg
#   inflating: landscape Images/gray/3472.jpg
#   inflating: landscape Images/gray/3473.jpg
#   inflating: landscape Images/gray/3474.jpg
#   inflating: landscape Images/gray/3475.jpg
#   inflating: landscape Images/gray/3476.jpg
#   inflating: landscape Images/gray/3477.jpg
#   inflating: landscape Images/gray/3478.jpg
#   inflating: landscape Images/gray/3479.jpg
#   inflating: landscape Images/gray/348.jpg
#   inflating: landscape Images/gray/3480.jpg
#   inflating: landscape Images/gray/3481.jpg
#   inflating: landscape Images/gray/3482.jpg
#   inflating: landscape Images/gray/3483.jpg
#   inflating: landscape Images/gray/3484.jpg
#   inflating: landscape Images/gray/3485.jpg
#   inflating: landscape Images/gray/3486.jpg
#   inflating: landscape Images/gray/3487.jpg
#   inflating: landscape Images/gray/3488.jpg
#   inflating: landscape Images/gray/3489.jpg
#   inflating: landscape Images/gray/349.jpg
#   inflating: landscape Images/gray/3490.jpg
#   inflating: landscape Images/gray/3491.jpg
#   inflating: landscape Images/gray/3492.jpg
#   inflating: landscape Images/gray/3493.jpg
#   inflating: landscape Images/gray/3494.jpg
#   inflating: landscape Images/gray/3495.jpg
#   inflating: landscape Images/gray/3496.jpg
#   inflating: landscape Images/gray/3497.jpg
#   inflating: landscape Images/gray/3498.jpg
#   inflating: landscape Images/gray/3499.jpg
#   inflating: landscape Images/gray/35.jpg
#   inflating: landscape Images/gray/350.jpg
#   inflating: landscape Images/gray/3500.jpg
#   inflating: landscape Images/gray/3501.jpg
#   inflating: landscape Images/gray/3502.jpg
#   inflating: landscape Images/gray/3503.jpg
#   inflating: landscape Images/gray/3504.jpg
#   inflating: landscape Images/gray/3505.jpg
#   inflating: landscape Images/gray/3506.jpg
#   inflating: landscape Images/gray/3507.jpg
#   inflating: landscape Images/gray/3508.jpg
#   inflating: landscape Images/gray/3509.jpg
#   inflating: landscape Images/gray/351.jpg
#   inflating: landscape Images/gray/3510.jpg
#   inflating: landscape Images/gray/3511.jpg
#   inflating: landscape Images/gray/3512.jpg
#   inflating: landscape Images/gray/3513.jpg
#   inflating: landscape Images/gray/3514.jpg
#   inflating: landscape Images/gray/3515.jpg
#   inflating: landscape Images/gray/3516.jpg
#   inflating: landscape Images/gray/3517.jpg
#   inflating: landscape Images/gray/3518.jpg
#   inflating: landscape Images/gray/3519.jpg
#   inflating: landscape Images/gray/352.jpg
#   inflating: landscape Images/gray/3520.jpg
#   inflating: landscape Images/gray/3521.jpg
#   inflating: landscape Images/gray/3522.jpg
#   inflating: landscape Images/gray/3523.jpg
#   inflating: landscape Images/gray/3524.jpg
#   inflating: landscape Images/gray/3525.jpg
#   inflating: landscape Images/gray/3526.jpg
#   inflating: landscape Images/gray/3527.jpg
#   inflating: landscape Images/gray/3528.jpg
#   inflating: landscape Images/gray/3529.jpg
#   inflating: landscape Images/gray/353.jpg
#   inflating: landscape Images/gray/3530.jpg
#   inflating: landscape Images/gray/3531.jpg
#   inflating: landscape Images/gray/3532.jpg
#   inflating: landscape Images/gray/3533.jpg
#   inflating: landscape Images/gray/3534.jpg
#   inflating: landscape Images/gray/3535.jpg
#   inflating: landscape Images/gray/3536.jpg
#   inflating: landscape Images/gray/3537.jpg
#   inflating: landscape Images/gray/3538.jpg
#   inflating: landscape Images/gray/3539.jpg
#   inflating: landscape Images/gray/354.jpg
#   inflating: landscape Images/gray/3540.jpg
#   inflating: landscape Images/gray/3541.jpg
#   inflating: landscape Images/gray/3542.jpg
#   inflating: landscape Images/gray/3543.jpg
#   inflating: landscape Images/gray/3544.jpg
#   inflating: landscape Images/gray/3545.jpg
#   inflating: landscape Images/gray/3546.jpg
#   inflating: landscape Images/gray/3547.jpg
#   inflating: landscape Images/gray/3548.jpg
#   inflating: landscape Images/gray/3549.jpg
#   inflating: landscape Images/gray/355.jpg
#   inflating: landscape Images/gray/3550.jpg
#   inflating: landscape Images/gray/3551.jpg
#   inflating: landscape Images/gray/3552.jpg
#   inflating: landscape Images/gray/3553.jpg
#   inflating: landscape Images/gray/3554.jpg
#   inflating: landscape Images/gray/3555.jpg
#   inflating: landscape Images/gray/3556.jpg
#   inflating: landscape Images/gray/3557.jpg
#   inflating: landscape Images/gray/3558.jpg
#   inflating: landscape Images/gray/3559.jpg
#   inflating: landscape Images/gray/356.jpg
#   inflating: landscape Images/gray/3560.jpg
#   inflating: landscape Images/gray/3561.jpg
#   inflating: landscape Images/gray/3562.jpg
#   inflating: landscape Images/gray/3563.jpg
#   inflating: landscape Images/gray/3564.jpg
#   inflating: landscape Images/gray/3565.jpg
#   inflating: landscape Images/gray/3566.jpg
#   inflating: landscape Images/gray/3567.jpg
#   inflating: landscape Images/gray/3568.jpg
#   inflating: landscape Images/gray/3569.jpg
#   inflating: landscape Images/gray/357.jpg
#   inflating: landscape Images/gray/3570.jpg
#   inflating: landscape Images/gray/3571.jpg
#   inflating: landscape Images/gray/3572.jpg
#   inflating: landscape Images/gray/3573.jpg
#   inflating: landscape Images/gray/3574.jpg
#   inflating: landscape Images/gray/3575.jpg
#   inflating: landscape Images/gray/3576.jpg
#   inflating: landscape Images/gray/3577.jpg
#   inflating: landscape Images/gray/3578.jpg
#   inflating: landscape Images/gray/3579.jpg
#   inflating: landscape Images/gray/358.jpg
#   inflating: landscape Images/gray/3580.jpg
#   inflating: landscape Images/gray/3581.jpg
#   inflating: landscape Images/gray/3582.jpg
#   inflating: landscape Images/gray/3583.jpg
#   inflating: landscape Images/gray/3584.jpg
#   inflating: landscape Images/gray/3585.jpg
#   inflating: landscape Images/gray/3586.jpg
#   inflating: landscape Images/gray/3587.jpg
#   inflating: landscape Images/gray/3588.jpg
#   inflating: landscape Images/gray/3589.jpg
#   inflating: landscape Images/gray/359.jpg
#   inflating: landscape Images/gray/3590.jpg
#   inflating: landscape Images/gray/3591.jpg
#   inflating: landscape Images/gray/3592.jpg
#   inflating: landscape Images/gray/3593.jpg
#   inflating: landscape Images/gray/3594.jpg
#   inflating: landscape Images/gray/3595.jpg
#   inflating: landscape Images/gray/3596.jpg
#   inflating: landscape Images/gray/3597.jpg
#   inflating: landscape Images/gray/3598.jpg
#   inflating: landscape Images/gray/3599.jpg
#   inflating: landscape Images/gray/36.jpg
#   inflating: landscape Images/gray/360.jpg
#   inflating: landscape Images/gray/3600.jpg
#   inflating: landscape Images/gray/3601.jpg
#   inflating: landscape Images/gray/3602.jpg
#   inflating: landscape Images/gray/3603.jpg
#   inflating: landscape Images/gray/3604.jpg
#   inflating: landscape Images/gray/3605.jpg
#   inflating: landscape Images/gray/3606.jpg
#   inflating: landscape Images/gray/3607.jpg
#   inflating: landscape Images/gray/3608.jpg
#   inflating: landscape Images/gray/3609.jpg
#   inflating: landscape Images/gray/361.jpg
#   inflating: landscape Images/gray/3610.jpg
#   inflating: landscape Images/gray/3611.jpg
#   inflating: landscape Images/gray/3612.jpg
#   inflating: landscape Images/gray/3613.jpg
#   inflating: landscape Images/gray/3614.jpg
#   inflating: landscape Images/gray/3615.jpg
#   inflating: landscape Images/gray/3616.jpg
#   inflating: landscape Images/gray/3617.jpg
#   inflating: landscape Images/gray/3618.jpg
#   inflating: landscape Images/gray/3619.jpg
#   inflating: landscape Images/gray/362.jpg
#   inflating: landscape Images/gray/3620.jpg
#   inflating: landscape Images/gray/3621.jpg
#   inflating: landscape Images/gray/3622.jpg
#   inflating: landscape Images/gray/3623.jpg
#   inflating: landscape Images/gray/3624.jpg
#   inflating: landscape Images/gray/3625.jpg
#   inflating: landscape Images/gray/3626.jpg
#   inflating: landscape Images/gray/3627.jpg
#   inflating: landscape Images/gray/3628.jpg
#   inflating: landscape Images/gray/3629.jpg
#   inflating: landscape Images/gray/363.jpg
#   inflating: landscape Images/gray/3630.jpg
#   inflating: landscape Images/gray/3631.jpg
#   inflating: landscape Images/gray/3632.jpg
#   inflating: landscape Images/gray/3633.jpg
#   inflating: landscape Images/gray/3634.jpg
#   inflating: landscape Images/gray/3635.jpg
#   inflating: landscape Images/gray/3636.jpg
#   inflating: landscape Images/gray/3637.jpg
#   inflating: landscape Images/gray/3638.jpg
#   inflating: landscape Images/gray/3639.jpg
#   inflating: landscape Images/gray/364.jpg
#   inflating: landscape Images/gray/3640.jpg
#   inflating: landscape Images/gray/3641.jpg
#   inflating: landscape Images/gray/3642.jpg
#   inflating: landscape Images/gray/3643.jpg
#   inflating: landscape Images/gray/3644.jpg
#   inflating: landscape Images/gray/3645.jpg
#   inflating: landscape Images/gray/3646.jpg
#   inflating: landscape Images/gray/3647.jpg
#   inflating: landscape Images/gray/3648.jpg
#   inflating: landscape Images/gray/3649.jpg
#   inflating: landscape Images/gray/365.jpg
#   inflating: landscape Images/gray/3650.jpg
#   inflating: landscape Images/gray/3651.jpg
#   inflating: landscape Images/gray/3652.jpg
#   inflating: landscape Images/gray/3653.jpg
#   inflating: landscape Images/gray/3654.jpg
#   inflating: landscape Images/gray/3655.jpg
#   inflating: landscape Images/gray/3656.jpg
#   inflating: landscape Images/gray/3657.jpg
#   inflating: landscape Images/gray/3658.jpg
#   inflating: landscape Images/gray/3659.jpg
#   inflating: landscape Images/gray/366.jpg
#   inflating: landscape Images/gray/3660.jpg
#   inflating: landscape Images/gray/3661.jpg
#   inflating: landscape Images/gray/3662.jpg
#   inflating: landscape Images/gray/3663.jpg
#   inflating: landscape Images/gray/3664.jpg
#   inflating: landscape Images/gray/3665.jpg
#   inflating: landscape Images/gray/3666.jpg
#   inflating: landscape Images/gray/3667.jpg
#   inflating: landscape Images/gray/3668.jpg
#   inflating: landscape Images/gray/3669.jpg
#   inflating: landscape Images/gray/367.jpg
#   inflating: landscape Images/gray/3670.jpg
#   inflating: landscape Images/gray/3671.jpg
#   inflating: landscape Images/gray/3672.jpg
#   inflating: landscape Images/gray/3673.jpg
#   inflating: landscape Images/gray/3674.jpg
#   inflating: landscape Images/gray/3675.jpg
#   inflating: landscape Images/gray/3676.jpg
#   inflating: landscape Images/gray/3677.jpg
#   inflating: landscape Images/gray/3678.jpg
#   inflating: landscape Images/gray/3679.jpg
#   inflating: landscape Images/gray/368.jpg
#   inflating: landscape Images/gray/3680.jpg
#   inflating: landscape Images/gray/3681.jpg
#   inflating: landscape Images/gray/3682.jpg
#   inflating: landscape Images/gray/3683.jpg
#   inflating: landscape Images/gray/3684.jpg
#   inflating: landscape Images/gray/3685.jpg
#   inflating: landscape Images/gray/3686.jpg
#   inflating: landscape Images/gray/3687.jpg
#   inflating: landscape Images/gray/3688.jpg
#   inflating: landscape Images/gray/3689.jpg
#   inflating: landscape Images/gray/369.jpg
#   inflating: landscape Images/gray/3690.jpg
#   inflating: landscape Images/gray/3691.jpg
#   inflating: landscape Images/gray/3692.jpg
#   inflating: landscape Images/gray/3693.jpg
#   inflating: landscape Images/gray/3694.jpg
#   inflating: landscape Images/gray/3695.jpg
#   inflating: landscape Images/gray/3696.jpg
#   inflating: landscape Images/gray/3697.jpg
#   inflating: landscape Images/gray/3698.jpg
#   inflating: landscape Images/gray/3699.jpg
#   inflating: landscape Images/gray/37.jpg
#   inflating: landscape Images/gray/370.jpg
#   inflating: landscape Images/gray/3700.jpg
#   inflating: landscape Images/gray/3701.jpg
#   inflating: landscape Images/gray/3702.jpg
#   inflating: landscape Images/gray/3703.jpg
#   inflating: landscape Images/gray/3704.jpg
#   inflating: landscape Images/gray/3705.jpg
#   inflating: landscape Images/gray/3706.jpg
#   inflating: landscape Images/gray/3707.jpg
#   inflating: landscape Images/gray/3708.jpg
#   inflating: landscape Images/gray/3709.jpg
#   inflating: landscape Images/gray/371.jpg
#   inflating: landscape Images/gray/3710.jpg
#   inflating: landscape Images/gray/3711.jpg
#   inflating: landscape Images/gray/3712.jpg
#   inflating: landscape Images/gray/3713.jpg
#   inflating: landscape Images/gray/3714.jpg
#   inflating: landscape Images/gray/3715.jpg
#   inflating: landscape Images/gray/3716.jpg
#   inflating: landscape Images/gray/3717.jpg
#   inflating: landscape Images/gray/3718.jpg
#   inflating: landscape Images/gray/3719.jpg
#   inflating: landscape Images/gray/372.jpg
#   inflating: landscape Images/gray/3720.jpg
#   inflating: landscape Images/gray/3721.jpg
#   inflating: landscape Images/gray/3722.jpg
#   inflating: landscape Images/gray/3723.jpg
#   inflating: landscape Images/gray/3724.jpg
#   inflating: landscape Images/gray/3725.jpg
#   inflating: landscape Images/gray/3726.jpg
#   inflating: landscape Images/gray/3727.jpg
#   inflating: landscape Images/gray/3728.jpg
#   inflating: landscape Images/gray/3729.jpg
#   inflating: landscape Images/gray/373.jpg
#   inflating: landscape Images/gray/3730.jpg
#   inflating: landscape Images/gray/3731.jpg
#   inflating: landscape Images/gray/3732.jpg
#   inflating: landscape Images/gray/3733.jpg
#   inflating: landscape Images/gray/3734.jpg
#   inflating: landscape Images/gray/3735.jpg
#   inflating: landscape Images/gray/3736.jpg
#   inflating: landscape Images/gray/3737.jpg
#   inflating: landscape Images/gray/3738.jpg
#   inflating: landscape Images/gray/3739.jpg
#   inflating: landscape Images/gray/374.jpg
#   inflating: landscape Images/gray/3740.jpg
#   inflating: landscape Images/gray/3741.jpg
#   inflating: landscape Images/gray/3742.jpg
#   inflating: landscape Images/gray/3743.jpg
#   inflating: landscape Images/gray/3744.jpg
#   inflating: landscape Images/gray/3745.jpg
#   inflating: landscape Images/gray/3746.jpg
#   inflating: landscape Images/gray/3747.jpg
#   inflating: landscape Images/gray/3748.jpg
#   inflating: landscape Images/gray/3749.jpg
#   inflating: landscape Images/gray/375.jpg
#   inflating: landscape Images/gray/3750.jpg
#   inflating: landscape Images/gray/3751.jpg
#   inflating: landscape Images/gray/3752.jpg
#   inflating: landscape Images/gray/3753.jpg
#   inflating: landscape Images/gray/3754.jpg
#   inflating: landscape Images/gray/3755.jpg
#   inflating: landscape Images/gray/3756.jpg
#   inflating: landscape Images/gray/3757.jpg
#   inflating: landscape Images/gray/3758.jpg
#   inflating: landscape Images/gray/3759.jpg
#   inflating: landscape Images/gray/376.jpg
#   inflating: landscape Images/gray/3760.jpg
#   inflating: landscape Images/gray/3761.jpg
#   inflating: landscape Images/gray/3762.jpg
#   inflating: landscape Images/gray/3763.jpg
#   inflating: landscape Images/gray/3764.jpg
#   inflating: landscape Images/gray/3765.jpg
#   inflating: landscape Images/gray/3766.jpg
#   inflating: landscape Images/gray/3767.jpg
#   inflating: landscape Images/gray/3768.jpg
#   inflating: landscape Images/gray/3769.jpg
#   inflating: landscape Images/gray/377.jpg
#   inflating: landscape Images/gray/3770.jpg
#   inflating: landscape Images/gray/3771.jpg
#   inflating: landscape Images/gray/3772.jpg
#   inflating: landscape Images/gray/3773.jpg
#   inflating: landscape Images/gray/3774.jpg
#   inflating: landscape Images/gray/3775.jpg
#   inflating: landscape Images/gray/3776.jpg
#   inflating: landscape Images/gray/3777.jpg
#   inflating: landscape Images/gray/3778.jpg
#   inflating: landscape Images/gray/3779.jpg
#   inflating: landscape Images/gray/378.jpg
#   inflating: landscape Images/gray/3780.jpg
#   inflating: landscape Images/gray/3781.jpg
#   inflating: landscape Images/gray/3782.jpg
#   inflating: landscape Images/gray/3783.jpg
#   inflating: landscape Images/gray/3784.jpg
#   inflating: landscape Images/gray/3785.jpg
#   inflating: landscape Images/gray/3786.jpg
#   inflating: landscape Images/gray/3787.jpg
#   inflating: landscape Images/gray/3788.jpg
#   inflating: landscape Images/gray/3789.jpg
#   inflating: landscape Images/gray/379.jpg
#   inflating: landscape Images/gray/3790.jpg
#   inflating: landscape Images/gray/3791.jpg
#   inflating: landscape Images/gray/3792.jpg
#   inflating: landscape Images/gray/3793.jpg
#   inflating: landscape Images/gray/3794.jpg
#   inflating: landscape Images/gray/3795.jpg
#   inflating: landscape Images/gray/3796.jpg
#   inflating: landscape Images/gray/3797.jpg
#   inflating: landscape Images/gray/3798.jpg
#   inflating: landscape Images/gray/3799.jpg
#   inflating: landscape Images/gray/38.jpg
#   inflating: landscape Images/gray/380.jpg
#   inflating: landscape Images/gray/3800.jpg
#   inflating: landscape Images/gray/3801.jpg
#   inflating: landscape Images/gray/3802.jpg
#   inflating: landscape Images/gray/3803.jpg
#   inflating: landscape Images/gray/3804.jpg
#   inflating: landscape Images/gray/3805.jpg
#   inflating: landscape Images/gray/3806.jpg
#   inflating: landscape Images/gray/3807.jpg
#   inflating: landscape Images/gray/3808.jpg
#   inflating: landscape Images/gray/3809.jpg
#   inflating: landscape Images/gray/381.jpg
#   inflating: landscape Images/gray/3810.jpg
#   inflating: landscape Images/gray/3811.jpg
#   inflating: landscape Images/gray/3812.jpg
#   inflating: landscape Images/gray/3813.jpg
#   inflating: landscape Images/gray/3814.jpg
#   inflating: landscape Images/gray/3815.jpg
#   inflating: landscape Images/gray/3816.jpg
#   inflating: landscape Images/gray/3817.jpg
#   inflating: landscape Images/gray/3818.jpg
#   inflating: landscape Images/gray/3819.jpg
#   inflating: landscape Images/gray/382.jpg
#   inflating: landscape Images/gray/3820.jpg
#   inflating: landscape Images/gray/3821.jpg
#   inflating: landscape Images/gray/3822.jpg
#   inflating: landscape Images/gray/3823.jpg
#   inflating: landscape Images/gray/3824.jpg
#   inflating: landscape Images/gray/3825.jpg
#   inflating: landscape Images/gray/3826.jpg
#   inflating: landscape Images/gray/3827.jpg
#   inflating: landscape Images/gray/3828.jpg
#   inflating: landscape Images/gray/3829.jpg
#   inflating: landscape Images/gray/383.jpg
#   inflating: landscape Images/gray/3830.jpg
#   inflating: landscape Images/gray/3831.jpg
#   inflating: landscape Images/gray/3832.jpg
#   inflating: landscape Images/gray/3833.jpg
#   inflating: landscape Images/gray/3834.jpg
#   inflating: landscape Images/gray/3835.jpg
#   inflating: landscape Images/gray/3836.jpg
#   inflating: landscape Images/gray/3837.jpg
#   inflating: landscape Images/gray/3838.jpg
#   inflating: landscape Images/gray/3839.jpg
#   inflating: landscape Images/gray/384.jpg
#   inflating: landscape Images/gray/3840.jpg
#   inflating: landscape Images/gray/3841.jpg
#   inflating: landscape Images/gray/3842.jpg
#   inflating: landscape Images/gray/3843.jpg
#   inflating: landscape Images/gray/3844.jpg
#   inflating: landscape Images/gray/3845.jpg
#   inflating: landscape Images/gray/3846.jpg
#   inflating: landscape Images/gray/3847.jpg
#   inflating: landscape Images/gray/3848.jpg
#   inflating: landscape Images/gray/3849.jpg
#   inflating: landscape Images/gray/385.jpg
#   inflating: landscape Images/gray/3850.jpg
#   inflating: landscape Images/gray/3851.jpg
#   inflating: landscape Images/gray/3852.jpg
#   inflating: landscape Images/gray/3853.jpg
#   inflating: landscape Images/gray/3854.jpg
# ...
#   inflating: landscape Images/gray/7095.jpg
#   inflating: landscape Images/gray/7096.jpg
#   inflating: landscape Images/gray/7097.jpg
#   inflating: landscape Images/gray/7098.jpg
#   inflating: landscape Images/gray/7099.jpg
#   inflating: landscape Images/gray/71.jpg
#   inflating: landscape Images/gray/710.jpg
#   inflating: landscape Images/gray/7100.jpg
#   inflating: landscape Images/gray/7101.jpg
#   inflating: landscape Images/gray/7102.jpg
#   inflating: landscape Images/gray/7103.jpg
#   inflating: landscape Images/gray/7104.jpg
#   inflating: landscape Images/gray/7105.jpg
#   inflating: landscape Images/gray/7106.jpg
#   inflating: landscape Images/gray/7107.jpg
#   inflating: landscape Images/gray/7108.jpg
#   inflating: landscape Images/gray/7109.jpg
#   inflating: landscape Images/gray/711.jpg
#   inflating: landscape Images/gray/7110.jpg
#   inflating: landscape Images/gray/7111.jpg
#   inflating: landscape Images/gray/7112.jpg
#   inflating: landscape Images/gray/7113.jpg
#   inflating: landscape Images/gray/7114.jpg
#   inflating: landscape Images/gray/7115.jpg
#   inflating: landscape Images/gray/7116.jpg
#   inflating: landscape Images/gray/7117.jpg
#   inflating: landscape Images/gray/7118.jpg
#   inflating: landscape Images/gray/7119.jpg
#   inflating: landscape Images/gray/712.jpg
#   inflating: landscape Images/gray/7120.jpg
#   inflating: landscape Images/gray/7121.jpg
#   inflating: landscape Images/gray/7122.jpg
#   inflating: landscape Images/gray/7123.jpg
#   inflating: landscape Images/gray/7124.jpg
#   inflating: landscape Images/gray/7125.jpg
#   inflating: landscape Images/gray/7126.jpg
#   inflating: landscape Images/gray/7127.jpg
#   inflating: landscape Images/gray/7128.jpg
#   inflating: landscape Images/gray/713.jpg
#   inflating: landscape Images/gray/714.jpg
#   inflating: landscape Images/gray/715.jpg
#   inflating: landscape Images/gray/716.jpg
#   inflating: landscape Images/gray/717.jpg
#   inflating: landscape Images/gray/718.jpg
#   inflating: landscape Images/gray/719.jpg
#   inflating: landscape Images/gray/72.jpg
#   inflating: landscape Images/gray/720.jpg
#   inflating: landscape Images/gray/721.jpg
#   inflating: landscape Images/gray/722.jpg
#   inflating: landscape Images/gray/723.jpg
#   inflating: landscape Images/gray/724.jpg
#   inflating: landscape Images/gray/725.jpg
#   inflating: landscape Images/gray/726.jpg
#   inflating: landscape Images/gray/727.jpg
#   inflating: landscape Images/gray/728.jpg
#   inflating: landscape Images/gray/729.jpg
#   inflating: landscape Images/gray/73.jpg
#   inflating: landscape Images/gray/730.jpg
#   inflating: landscape Images/gray/731.jpg
#   inflating: landscape Images/gray/732.jpg
#   inflating: landscape Images/gray/733.jpg
#   inflating: landscape Images/gray/734.jpg
#   inflating: landscape Images/gray/735.jpg
#   inflating: landscape Images/gray/736.jpg
#   inflating: landscape Images/gray/737.jpg
#   inflating: landscape Images/gray/738.jpg
#   inflating: landscape Images/gray/739.jpg
#   inflating: landscape Images/gray/74.jpg
#   inflating: landscape Images/gray/740.jpg
#   inflating: landscape Images/gray/741.jpg
#   inflating: landscape Images/gray/742.jpg
#   inflating: landscape Images/gray/743.jpg
#   inflating: landscape Images/gray/744.jpg
#   inflating: landscape Images/gray/745.jpg
#   inflating: landscape Images/gray/746.jpg
#   inflating: landscape Images/gray/747.jpg
#   inflating: landscape Images/gray/748.jpg
#   inflating: landscape Images/gray/749.jpg
#   inflating: landscape Images/gray/75.jpg
#   inflating: landscape Images/gray/750.jpg
#   inflating: landscape Images/gray/751.jpg
#   inflating: landscape Images/gray/752.jpg
#   inflating: landscape Images/gray/753.jpg
#   inflating: landscape Images/gray/754.jpg
#   inflating: landscape Images/gray/755.jpg
#   inflating: landscape Images/gray/756.jpg
#   inflating: landscape Images/gray/757.jpg
#   inflating: landscape Images/gray/758.jpg
#   inflating: landscape Images/gray/759.jpg
#   inflating: landscape Images/gray/76.jpg
#   inflating: landscape Images/gray/760.jpg
#   inflating: landscape Images/gray/761.jpg
#   inflating: landscape Images/gray/762.jpg
#   inflating: landscape Images/gray/763.jpg
#   inflating: landscape Images/gray/764.jpg
#   inflating: landscape Images/gray/765.jpg
#   inflating: landscape Images/gray/766.jpg
#   inflating: landscape Images/gray/767.jpg
#   inflating: landscape Images/gray/768.jpg
#   inflating: landscape Images/gray/769.jpg
#   inflating: landscape Images/gray/77.jpg
#   inflating: landscape Images/gray/770.jpg
#   inflating: landscape Images/gray/771.jpg
#   inflating: landscape Images/gray/772.jpg
#   inflating: landscape Images/gray/773.jpg
#   inflating: landscape Images/gray/774.jpg
#   inflating: landscape Images/gray/775.jpg
#   inflating: landscape Images/gray/776.jpg
#   inflating: landscape Images/gray/777.jpg
#   inflating: landscape Images/gray/778.jpg
#   inflating: landscape Images/gray/779.jpg
#   inflating: landscape Images/gray/78.jpg
#   inflating: landscape Images/gray/780.jpg
#   inflating: landscape Images/gray/781.jpg
#   inflating: landscape Images/gray/782.jpg
#   inflating: landscape Images/gray/783.jpg
#   inflating: landscape Images/gray/784.jpg
#   inflating: landscape Images/gray/785.jpg
#   inflating: landscape Images/gray/786.jpg
#   inflating: landscape Images/gray/787.jpg
#   inflating: landscape Images/gray/788.jpg
#   inflating: landscape Images/gray/789.jpg
#   inflating: landscape Images/gray/79.jpg
#   inflating: landscape Images/gray/790.jpg
#   inflating: landscape Images/gray/791.jpg
#   inflating: landscape Images/gray/792.jpg
#   inflating: landscape Images/gray/793.jpg
#   inflating: landscape Images/gray/794.jpg
#   inflating: landscape Images/gray/795.jpg
#   inflating: landscape Images/gray/796.jpg
#   inflating: landscape Images/gray/797.jpg
#   inflating: landscape Images/gray/798.jpg
#   inflating: landscape Images/gray/799.jpg
#   inflating: landscape Images/gray/8.jpg
#   inflating: landscape Images/gray/80.jpg
#   inflating: landscape Images/gray/800.jpg
#   inflating: landscape Images/gray/801.jpg
#   inflating: landscape Images/gray/802.jpg
#   inflating: landscape Images/gray/803.jpg
#   inflating: landscape Images/gray/804.jpg
#   inflating: landscape Images/gray/805.jpg
#   inflating: landscape Images/gray/806.jpg
#   inflating: landscape Images/gray/807.jpg
#   inflating: landscape Images/gray/808.jpg
#   inflating: landscape Images/gray/809.jpg
#   inflating: landscape Images/gray/81.jpg
#   inflating: landscape Images/gray/810.jpg
#   inflating: landscape Images/gray/811.jpg
#   inflating: landscape Images/gray/812.jpg
#   inflating: landscape Images/gray/813.jpg
#   inflating: landscape Images/gray/814.jpg
#   inflating: landscape Images/gray/815.jpg
#   inflating: landscape Images/gray/816.jpg
#   inflating: landscape Images/gray/817.jpg
#   inflating: landscape Images/gray/818.jpg
#   inflating: landscape Images/gray/819.jpg
#   inflating: landscape Images/gray/82.jpg
#   inflating: landscape Images/gray/820.jpg
#   inflating: landscape Images/gray/821.jpg
#   inflating: landscape Images/gray/822.jpg
#   inflating: landscape Images/gray/823.jpg
#   inflating: landscape Images/gray/824.jpg
#   inflating: landscape Images/gray/825.jpg
#   inflating: landscape Images/gray/826.jpg
#   inflating: landscape Images/gray/827.jpg
#   inflating: landscape Images/gray/828.jpg
#   inflating: landscape Images/gray/829.jpg
#   inflating: landscape Images/gray/83.jpg
#   inflating: landscape Images/gray/830.jpg
#   inflating: landscape Images/gray/831.jpg
#   inflating: landscape Images/gray/832.jpg
#   inflating: landscape Images/gray/833.jpg
#   inflating: landscape Images/gray/834.jpg
#   inflating: landscape Images/gray/835.jpg
#   inflating: landscape Images/gray/836.jpg
#   inflating: landscape Images/gray/837.jpg
#   inflating: landscape Images/gray/838.jpg
#   inflating: landscape Images/gray/839.jpg
#   inflating: landscape Images/gray/84.jpg
#   inflating: landscape Images/gray/840.jpg
#   inflating: landscape Images/gray/841.jpg
#   inflating: landscape Images/gray/842.jpg
#   inflating: landscape Images/gray/843.jpg
#   inflating: landscape Images/gray/844.jpg
#   inflating: landscape Images/gray/845.jpg
#   inflating: landscape Images/gray/846.jpg
#   inflating: landscape Images/gray/847.jpg
#   inflating: landscape Images/gray/848.jpg
#   inflating: landscape Images/gray/849.jpg
#   inflating: landscape Images/gray/85.jpg
#   inflating: landscape Images/gray/850.jpg
#   inflating: landscape Images/gray/851.jpg
#   inflating: landscape Images/gray/852.jpg
#   inflating: landscape Images/gray/853.jpg
#   inflating: landscape Images/gray/854.jpg
#   inflating: landscape Images/gray/855.jpg
#   inflating: landscape Images/gray/856.jpg
#   inflating: landscape Images/gray/857.jpg
#   inflating: landscape Images/gray/858.jpg
#   inflating: landscape Images/gray/859.jpg
#   inflating: landscape Images/gray/86.jpg
#   inflating: landscape Images/gray/860.jpg
#   inflating: landscape Images/gray/861.jpg
#   inflating: landscape Images/gray/862.jpg
#   inflating: landscape Images/gray/863.jpg
#   inflating: landscape Images/gray/864.jpg
#   inflating: landscape Images/gray/865.jpg
#   inflating: landscape Images/gray/866.jpg
#   inflating: landscape Images/gray/867.jpg
#   inflating: landscape Images/gray/868.jpg
#   inflating: landscape Images/gray/869.jpg
#   inflating: landscape Images/gray/87.jpg
#   inflating: landscape Images/gray/870.jpg
#   inflating: landscape Images/gray/871.jpg
#   inflating: landscape Images/gray/872.jpg
#   inflating: landscape Images/gray/873.jpg
#   inflating: landscape Images/gray/874.jpg
#   inflating: landscape Images/gray/875.jpg
#   inflating: landscape Images/gray/876.jpg
#   inflating: landscape Images/gray/877.jpg
#   inflating: landscape Images/gray/878.jpg
#   inflating: landscape Images/gray/879.jpg
#   inflating: landscape Images/gray/88.jpg
#   inflating: landscape Images/gray/880.jpg
#   inflating: landscape Images/gray/881.jpg
#   inflating: landscape Images/gray/882.jpg
#   inflating: landscape Images/gray/883.jpg
#   inflating: landscape Images/gray/884.jpg
#   inflating: landscape Images/gray/885.jpg
#   inflating: landscape Images/gray/886.jpg
#   inflating: landscape Images/gray/887.jpg
#   inflating: landscape Images/gray/888.jpg
#   inflating: landscape Images/gray/889.jpg
#   inflating: landscape Images/gray/89.jpg
#   inflating: landscape Images/gray/890.jpg
#   inflating: landscape Images/gray/891.jpg
#   inflating: landscape Images/gray/892.jpg
#   inflating: landscape Images/gray/893.jpg
#   inflating: landscape Images/gray/894.jpg
#   inflating: landscape Images/gray/895.jpg
#   inflating: landscape Images/gray/896.jpg
#   inflating: landscape Images/gray/897.jpg
#   inflating: landscape Images/gray/898.jpg
#   inflating: landscape Images/gray/899.jpg
#   inflating: landscape Images/gray/9.jpg
#   inflating: landscape Images/gray/90.jpg
#   inflating: landscape Images/gray/900.jpg
#   inflating: landscape Images/gray/901.jpg
#   inflating: landscape Images/gray/902.jpg
#   inflating: landscape Images/gray/903.jpg
#   inflating: landscape Images/gray/904.jpg
#   inflating: landscape Images/gray/905.jpg
#   inflating: landscape Images/gray/906.jpg
#   inflating: landscape Images/gray/907.jpg
#   inflating: landscape Images/gray/908.jpg
#   inflating: landscape Images/gray/909.jpg
#   inflating: landscape Images/gray/91.jpg
#   inflating: landscape Images/gray/910.jpg
#   inflating: landscape Images/gray/911.jpg
#   inflating: landscape Images/gray/912.jpg
#   inflating: landscape Images/gray/913.jpg
#   inflating: landscape Images/gray/914.jpg
#   inflating: landscape Images/gray/915.jpg
#   inflating: landscape Images/gray/916.jpg
#   inflating: landscape Images/gray/917.jpg
#   inflating: landscape Images/gray/918.jpg
#   inflating: landscape Images/gray/919.jpg
#   inflating: landscape Images/gray/92.jpg
#   inflating: landscape Images/gray/920.jpg
#   inflating: landscape Images/gray/921.jpg
#   inflating: landscape Images/gray/922.jpg
#   inflating: landscape Images/gray/923.jpg
#   inflating: landscape Images/gray/924.jpg
#   inflating: landscape Images/gray/925.jpg
#   inflating: landscape Images/gray/926.jpg
#   inflating: landscape Images/gray/927.jpg
#   inflating: landscape Images/gray/928.jpg
#   inflating: landscape Images/gray/929.jpg
#   inflating: landscape Images/gray/93.jpg
#   inflating: landscape Images/gray/930.jpg
#   inflating: landscape Images/gray/931.jpg
#   inflating: landscape Images/gray/932.jpg
#   inflating: landscape Images/gray/933.jpg
#   inflating: landscape Images/gray/934.jpg
#   inflating: landscape Images/gray/935.jpg
#   inflating: landscape Images/gray/936.jpg
#   inflating: landscape Images/gray/937.jpg
#   inflating: landscape Images/gray/938.jpg
#   inflating: landscape Images/gray/939.jpg
#   inflating: landscape Images/gray/94.jpg
#   inflating: landscape Images/gray/940.jpg
#   inflating: landscape Images/gray/941.jpg
#   inflating: landscape Images/gray/942.jpg
#   inflating: landscape Images/gray/943.jpg
#   inflating: landscape Images/gray/944.jpg
#   inflating: landscape Images/gray/945.jpg
#   inflating: landscape Images/gray/946.jpg
#   inflating: landscape Images/gray/947.jpg
#   inflating: landscape Images/gray/948.jpg
#   inflating: landscape Images/gray/949.jpg
#   inflating: landscape Images/gray/95.jpg
#   inflating: landscape Images/gray/950.jpg
#   inflating: landscape Images/gray/951.jpg
#   inflating: landscape Images/gray/952.jpg
#   inflating: landscape Images/gray/953.jpg
#   inflating: landscape Images/gray/954.jpg
#   inflating: landscape Images/gray/955.jpg
#   inflating: landscape Images/gray/956.jpg
#   inflating: landscape Images/gray/957.jpg
#   inflating: landscape Images/gray/958.jpg
#   inflating: landscape Images/gray/959.jpg
#   inflating: landscape Images/gray/96.jpg
#   inflating: landscape Images/gray/960.jpg
#   inflating: landscape Images/gray/961.jpg
#   inflating: landscape Images/gray/962.jpg
#   inflating: landscape Images/gray/963.jpg
#   inflating: landscape Images/gray/964.jpg
#   inflating: landscape Images/gray/965.jpg
#   inflating: landscape Images/gray/966.jpg
#   inflating: landscape Images/gray/967.jpg
#   inflating: landscape Images/gray/968.jpg
#   inflating: landscape Images/gray/969.jpg
#   inflating: landscape Images/gray/97.jpg
#   inflating: landscape Images/gray/970.jpg
#   inflating: landscape Images/gray/971.jpg
#   inflating: landscape Images/gray/972.jpg
#   inflating: landscape Images/gray/973.jpg
#   inflating: landscape Images/gray/974.jpg
#   inflating: landscape Images/gray/975.jpg
#   inflating: landscape Images/gray/976.jpg
#   inflating: landscape Images/gray/977.jpg
#   inflating: landscape Images/gray/978.jpg
#   inflating: landscape Images/gray/979.jpg
#   inflating: landscape Images/gray/98.jpg
#   inflating: landscape Images/gray/980.jpg
#   inflating: landscape Images/gray/981.jpg
#   inflating: landscape Images/gray/982.jpg
#   inflating: landscape Images/gray/983.jpg
#   inflating: landscape Images/gray/984.jpg
#   inflating: landscape Images/gray/985.jpg
#   inflating: landscape Images/gray/986.jpg
#   inflating: landscape Images/gray/987.jpg
#   inflating: landscape Images/gray/988.jpg
#   inflating: landscape Images/gray/989.jpg
#   inflating: landscape Images/gray/99.jpg
#   inflating: landscape Images/gray/990.jpg
#   inflating: landscape Images/gray/991.jpg
#   inflating: landscape Images/gray/992.jpg
#   inflating: landscape Images/gray/993.jpg
#   inflating: landscape Images/gray/994.jpg
#   inflating: landscape Images/gray/995.jpg
#   inflating: landscape Images/gray/996.jpg
#   inflating: landscape Images/gray/997.jpg
#   inflating: landscape Images/gray/998.jpg
#   inflating: landscape Images/gray/999.jpg

# %%
color_folder = "/content/drive/MyDrive/Colab Notebooks/landscape Images/color"  # Replace with the path to your image folder
gray_folder ="/content/drive/MyDrive/Colab Notebooks/landscape Images/gray"

color_files=os.listdir(color_folder)
gray_files=os.listdir(gray_folder)
x=[]
y=[]
y_show=[]

image_files = [filename for filename in os.listdir(color_folder) if filename.endswith('.jpg')]
sorted_color_files = sorted(image_files, key=lambda x: int(x.split('.')[0]))

image_files = [filename for filename in os.listdir(gray_folder) if filename.endswith('.jpg')]
sorted_gray_files = sorted(image_files, key=lambda x: int(x.split('.')[0]))



transform = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize((0.0,), (1.0,))

])







for file_name in sorted_gray_files:
    file_path = os.path.join(gray_folder, file_name)

    image_pil = Image.open(file_path)
    transformed_image = transform(image_pil)
    image_np = np.array(transformed_image)
    x.append(image_np)


for file_name in sorted_color_files:
    file_path = os.path.join(color_folder, file_name)

    image_pil = Image.open(file_path)
    transformed_image = transform(image_pil)
    image_np = np.array(transformed_image)
    y.append(image_np)

for file_name in sorted_color_files:
    file_path = os.path.join(color_folder, file_name)

    image_pil = Image.open(file_path)
    image_pil = image_pil.resize((150, 150))
    image_np = np.array(image_pil)
    y_show.append(image_np)

x = np.array(x)
y = np.array(y)
y_show=np.array(y_show)



print(x.shape)
print(y.shape)
print(y_show.shape)
# Out:
# (7129, 1, 150, 150)
# (7129, 3, 150, 150)
# (7129, 150, 150, 3)

# %%
plt.imshow(x[0].squeeze(),cmap='gray')
plt.axis('off')
plt.show()


plt.imshow(y[0].transpose(1, 2, 0))
plt.axis('off')  # Remove axis ticks
plt.show()

plt.imshow(y_show[0])
plt.axis('off')  # Remove axis ticks
plt.show()

#print(x[0])
#print(y[0].shape)

# %%
class CustomDataset(Dataset):
    def __init__(self, x, y ):
        self.x = x
        self.y = y


    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        feature = self.x[idx]
        label = self.y[idx]
        feature=torch.tensor(feature,dtype=torch.float)
        labels=torch.tensor(label,dtype=torch.float)

        return feature, labels

# %%
def loader(x,y):

  dataset = CustomDataset(x,y)

  train_size = int(0.8 * len(dataset))
  test_size = len(dataset) - train_size

  print(train_size)
  print(test_size)
  train_dataset,teset_dataset =random_split(dataset,[train_size, test_size])

  train_dataloader = DataLoader(train_dataset ,batch_size=64, shuffle=True)
  test_dataloader=DataLoader(teset_dataset ,batch_size=64, shuffle=False)

  return train_dataloader ,test_dataloader

# %%
train_dataloader ,test_dataloader=loader(x,y)
# Out:
# 5703
# 1426

# %%
class ColorizationModel(nn.Module):
    def __init__(self):
        super(ColorizationModel, self).__init__()


        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1), #32 150-3+2 = 149*149
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1), #64 [149-3+2*1]/2=74
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1), # 128 [74-3+2*1]/1=73
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1), # 256 [73-3=2*1]/2 =36
            nn.ReLU()
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
class VAE(nn.Module):
    def __init__(self, latent_dim):
        super(VAE, self).__init__()

        self.latent_dim = latent_dim

        # Encoder layers
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.ReLU()
        )
        with torch.no_grad():
            dummy_input = torch.zeros(1, 1, 150, 150)  # Replace height and width with the actual values
            encoded_shape = self.encoder(dummy_input).shape[1:]
            self.num_features = encoded_shape.numel()

        # Latent space layers
        self.fc_mu = nn.Linear(self.num_features, self.latent_dim)
        self.fc_logvar = nn.Linear(self.num_features, self.latent_dim)

        # Decoder layers
        self.decoder = nn.Sequential(
            nn.Linear(self.latent_dim, self.num_features),
            nn.ReLU(),
            nn.Unflatten(1, encoded_shape),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def encode(self, x):
        encoded = self.encoder(x)
        encoded = encoded.view(-1, self.num_features)
        mu = self.fc_mu(encoded)
        logvar = self.fc_logvar(encoded)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        z = mu + eps * std
        return z

    def decode(self, z):
        decoded = self.decoder(z)
        return decoded

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        x_recon = self.decode(z)
        return x_recon, mu, logvar

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device):
    model.train()

    train_loss =[]
    for batch, (X, y) in enumerate(dataloader):
        X,y= X.to(device) , y.to(device)
        y_resized = F.interpolate(y, size=(152, 152), mode='bilinear', align_corners=False)

        y_pred = model(X)

        loss = loss_fn(y_pred, y_resized)
        train_loss.append(loss.item()* X.size(0))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


    train_loss =sum(train_loss) / len(train_loss)

    return train_loss








def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device):

    test_loss= []
    with torch.inference_mode():
        for batch, (X,y) in enumerate(dataloader):
            X,y= X.to(device) , y.to(device)
            y_resized = F.interpolate(y, size=(152, 152), mode='bilinear', align_corners=False)
            y_pred = model(X)

            loss = loss_fn(y_pred, y_resized)
            test_loss.append(loss.item()* X.size(0))



    test_loss =sum(test_loss) / len(test_loss)
    return test_loss









def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device) -> Dict[str, List]:
    results = {"train_loss": [],
               "test_loss": [],
               }
    model.to(device)

    for epoch in tqdm(range(epochs)):
        train_loss  = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer,
                                           device=device)
        test_loss = test_step(model=model,
                                        dataloader=test_dataloader,
                                        loss_fn=loss_fn,
                                        device=device)

        print(
        f"Epoch: {epoch + 1} | "
        f"train_loss: {train_loss:.4f} | "
        f"test_loss: {test_loss:.4f} | "
        )


        results["train_loss"].append(train_loss)
        results["test_loss"].append(test_loss)

    return results







def vae_loss(y, y_pred, mu, logvar):
    reconstruction_error = nn.functional.mse_loss(y_pred, y, reduction='sum')
   # reconstruction_error = nn.functional.binary_cross_entropy(y_pred, y, reduction='sum')
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    vae_loss = reconstruction_error + kl_divergence

    return vae_loss










def train_vae(
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          epochs: int,
          device: torch.device) :


  train_losses = []




  for epoch in range(epochs):
    for i, (x, y) in enumerate(train_dataloader):
      x = x.to(device)
      y = y.to(device)
      y= F.interpolate(y, size=(152, 152), mode='bilinear', align_corners=False)


      # Zero out the gradients
      optimizer.zero_grad()

      # Forward pass through the encoder and decoder networks
      y_pred, mu, logvar = vae(x)


      # Compute the VAE loss and backpropagate the gradients
      loss = vae_loss(y, y_pred, mu, logvar)
      loss.backward()
      optimizer.step()



      # Print the loss every 50 batches
     # if (i+1) % 50 == 0:
       # print(f'Epoch [{epoch+1}/{epochs}], Batch [{i+1}/{len(train_dataloader)}], Loss: {loss.data.item():.4f}')


      if i % 100 == 0:
              print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(
                    epoch+1, epochs, i, len(train_dataloader), loss.item()))
              train_losses.append(loss.item())









  return train_losses









def plot_loss_curves_vae(results, title):



    epochs = range(len(results))

    plt.figure(figsize=(12, 4))
    plt.suptitle(title, fontsize=15)

     # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, results, label="train_loss")
    plt.title("Loss")
    plt.xlabel("step")
    plt.legend()








def plot_loss_curves(results, title):
    train_loss = results["train_loss"]
    test_loss = results["test_loss"]

    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(12, 4))
    plt.suptitle(title, fontsize=15)

     # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, label="train_loss")
    plt.plot(epochs, test_loss, label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
model = ColorizationModel().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

results = train(
    model,
    train_dataloader,
    test_dataloader,
    optimizer,
    criterion,
    epochs=20,
    device=device)

plot_loss_curves(results, title="encoder_decoder")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.2509 | test_loss: 0.1802 |
# Epoch: 2 | train_loss: 0.1711 | test_loss: 0.1536 |
# Epoch: 3 | train_loss: 0.1589 | test_loss: 0.1520 |
# Epoch: 4 | train_loss: 0.1518 | test_loss: 0.1570 |
# Epoch: 5 | train_loss: 0.1493 | test_loss: 0.1388 |
# Epoch: 6 | train_loss: 0.1434 | test_loss: 0.1385 |
# Epoch: 7 | train_loss: 0.1423 | test_loss: 0.1416 |
# Epoch: 8 | train_loss: 0.1406 | test_loss: 0.1341 |
# Epoch: 9 | train_loss: 0.1382 | test_loss: 0.1345 |
# Epoch: 10 | train_loss: 0.1376 | test_loss: 0.1330 |
# Epoch: 11 | train_loss: 0.1368 | test_loss: 0.1321 |
# Epoch: 12 | train_loss: 0.1343 | test_loss: 0.1284 |
# Epoch: 13 | train_loss: 0.1341 | test_loss: 0.1384 |
# Epoch: 14 | train_loss: 0.1334 | test_loss: 0.1275 |
# Epoch: 15 | train_loss: 0.1325 | test_loss: 0.1266 |
# Epoch: 16 | train_loss: 0.1318 | test_loss: 0.1271 |
# Epoch: 17 | train_loss: 0.1304 | test_loss: 0.1272 |
# Epoch: 18 | train_loss: 0.1294 | test_loss: 0.1250 |
# Epoch: 19 | train_loss: 0.1279 | test_loss: 0.1261 |
# Epoch: 20 | train_loss: 0.1286 | test_loss: 0.1253 |

# %%
for i, (features, labels) in enumerate(test_dataloader):
    if i == 53:
        x_test =features[0]
        y_test=labels[0]
        break




x_test=x_test.to(device)


with torch.no_grad():
    out=model(x_test).to(device)
    out=out.cpu().squeeze().detach().numpy()
    out=out.transpose(1, 2, 0)



plt.imshow(out)
plt.show()

y_test=y_test.numpy()
plt.imshow(y_test.transpose(1, 2, 0))
plt.show()

# %%
latent_dim =100
learning_rate = 0.001
vae = VAE(latent_dim).to(device)
optimizer = torch.optim.Adam(vae.parameters(), lr=learning_rate)


results=train_vae(
          train_dataloader,
          test_dataloader,
          optimizer=optimizer ,
          epochs=30,
          device=device)

plot_loss_curves_vae(results, title="VAE")
# Out:
# Epoch [1/30], Step [0/90], Loss: 372913.6875
# Epoch [2/30], Step [0/90], Loss: 148281.5156
# Epoch [3/30], Step [0/90], Loss: 129956.5625
# Epoch [4/30], Step [0/90], Loss: 116712.0625
# Epoch [5/30], Step [0/90], Loss: 109952.1094
# Epoch [6/30], Step [0/90], Loss: 108216.0469

# %%
for i, (features, labels) in enumerate(test_dataloader):
    if i == 25:
        x_test =features[0]
        y_test=labels[0]
        break



x_test=x_test.to(device)


with torch.no_grad():
    out,mu, logvar = vae(x_test)
    out=out.cpu().squeeze().detach().numpy()
    out=out.transpose(1, 2, 0)



plt.imshow(out)
plt.show()

y_test=y_test.numpy()
plt.imshow(y_test.transpose(1, 2, 0))
plt.show()

# %%
vae.eval()

# Generate new samples
with torch.no_grad():
    # Sample random values from the latent space
    z = torch.randn(128, latent_dim).to(device)

    # Decode the latent space values into images
    generated_images = vae.decode(z)

# Print or visualize the generated images
print(generated_images[1].shape)

out=generated_images[1]
out=out.cpu().detach().numpy()
out=out.transpose(1, 2, 0)

plt.imshow(out)
plt.show()
# Out:
# torch.Size([3, 152, 152])
